# %%
# loading packages
library(readr)
library(ggplot2)
library(dplyr)
library(tidyverse)
# Out:
# Registered S3 method overwritten by 'rvest':
#   method            from
#   read_xml.response xml2
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ tibble  3.0.3     ✔ purrr   0.3.4
# ✔ tidyr   1.1.1     ✔ stringr 1.4.0
# ✔ tibble  3.0.3     ✔ forcats 0.4.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
# look at the dataset
confirmed_cases = read_csv(file = 'covid_confirmed_usafacts.csv')

#see result
confirmed_cases
# Out:
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   `County Name` = col_character(),
#   State = col_character()
# )
# See spec(...) for full column specifications.
#      countyFIPS County Name           State stateFIPS 1/22/20 1/23/20 1/24/20
# 1       0       Statewide Unallocated AL    1         0       0       0
# 2    1001       Autauga County        AL    1         0       0       0
# 3    1003       Baldwin County        AL    1         0       0       0
# 4    1005       Barbour County        AL    1         0       0       0
# 5    1007       Bibb County           AL    1         0       0       0
# 6    1009       Blount County         AL    1         0       0       0
# 7    1011       Bullock County        AL    1         0       0       0
# 8    1013       Butler County         AL    1         0       0       0
# 9    1015       Calhoun County        AL    1         0       0       0
# ...

# %%
#check if it is a dataframe
is.data.frame(confirmed_cases) # all good
# Out:
# [1] TRUE

# %%
# initial data exploration 

ggplot(data = confimred_cases, aes(x = state, y = '7/10/20')) + 
    geom_bar(stat = identity)
# Out:
# Error in ggplot(data = confimred_cases, aes(x = state, y = "7/10/20")): object 'confimred_cases' not found
# Traceback:
#
# 1. ggplot(data = confimred_cases, aes(x = state, y = "7/10/20"))
